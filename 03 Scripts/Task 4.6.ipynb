# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\jacks\OneDrive\Documents\Elise\Instacart-Basket'

# %%
# 3. In a new notebook, import the orders_products_combined dataframe from the PICKLE file you just saved.
# Anwers to Task 4.6, No. 3-9"

# %%
df_ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#   4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

df_ords_prods_comb
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32640693   2977660   206209    prior            13          1
# 32640694   2977660   206209    prior            13          1
# 32640695   2977660   206209    prior            13          1
# 32640696   2977660   206209    prior            13          1
# 32640697    272231   206209    train            14          6
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN       196.0
# 1                         8                     NaN     14084.0
# ...

# %%
df_ords_prods_comb.shape    # Yest, its the same.
# Out:
# (32640698, 11)

# %%
# 5.Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# Importing 'products_cleaned.csv

df_prods_cleaned= pd.read_csv(r'C:\Users\jacks\OneDrive\Documents\Elise\Instacart-Basket\02 Data\Prepared Data\products_cleaned.csv', index_col=[0])

# %%
df_prods_cleaned.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods_cleaned.shape
# Out:
# (49677, 5)

# %%
# Merging 2 DataFrames: 'orders_products_combined.pkl' and 'products_cleaned.csv

# %%
# Dont forget to find the column in common to merge your data sets.
# Dropping '_merge' column from 'orders_products_combined.pkl'\n",

df_ords_prods_comb = df_ords_prods_comb.drop(columns = ['_merge'])

# %%
df_ords_prods_comb = df_ords_prods_comb.drop(columns = ['eval_set'])

# %%
# 'product_id' is a commom column
# Merging

df_ords_prods_merged = df_ords_prods_comb.merge(df_prods_cleaned, on = 'product_id', indicator = True)

# %%
 # 6. Confirm the results of the merge using the merge flag.

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2398795        1             2          3                  7
# 2           473747        1             3          3                 12
# 3          2254736        1             4          4                  7
# 4           431534        1             5          4                 15
# ...            ...      ...           ...        ...                ...
# 32406036   1320836   202557            17          2                 15
# 32406037     31526   202557            18          5                 11
# 32406038    758936   203436             1          2                  7
# 32406039   2745165   203436             2          3                  5
# 32406040   3093936   205420             1          4                 14
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32406041
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_ords_prods_merged.shape
# Out:
# (32406041, 14)

# %%
#  7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).
   # Import to PKL

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
